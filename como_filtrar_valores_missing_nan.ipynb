# %% [markdown]
# <a href="https://colab.research.google.com/github/KARINAgoncalvesSOARES/Pandas/blob/main/como_filtrar_valores_missing_nan.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## <h2 align="center">Filtrando valores NaN</h2>
#
# Data Scientist Jr.: Karina gonçalves Soares

# %% [markdown]
# Link de estudo:
#
# * [Python PANDAS - Como filtrar valores missing (nan)](https://www.youtube.com/watch?v=5KB-N_3sNs0&list=PLEdfCNsWt0gxURVswsV_STMrCo_n7rD5M&index=5&ab_channel=ProgramePython)

# %%
import pandas as pd
import numpy as np

# %%
dados = [[6.0, np.nan, 15.0 ], [np.nan, 15.0, np.nan], [16.0, 1.0, np.nan], [4.0 ,19.0, 16.0], [16, 8, 10], [12, 9, 11]]

# %%
df = pd.DataFrame(dados, columns=['col1','col2','col3'])
df
# Out:
#    col1  col2  col3
# 0   6.0   NaN  15.0
# 1   NaN  15.0   NaN
# 2  16.0   1.0   NaN
# 3   4.0  19.0  16.0
# 4  16.0   8.0  10.0
# 5  12.0   9.0  11.0

# %%
#.isnull(), etorna apenas as linhas que tem o valor missing(nan)
df[df['col3'].isnull()]
# Out:
#    col1  col2  col3
# 1   NaN  15.0   NaN
# 2  16.0   1.0   NaN

# %%
#.notnull(), retorna apenas as linhas que NÃO possuem valor missing(nan)

df[df['col3'].notnull()]
# Out:
#    col1  col2  col3
# 0   6.0   NaN  15.0
# 3   4.0  19.0  16.0
# 4  16.0   8.0  10.0
# 5  12.0   9.0  11.0

# %%
# o "~" nega a função,no caso dando o mesmo objetivo do notnull.
df[~df['col3'].isnull()]
# Out:
#    col1  col2  col3
# 0   6.0   NaN  15.0
# 3   4.0  19.0  16.0
# 4  16.0   8.0  10.0
# 5  12.0   9.0  11.0

# %%
#.isna() tem a mesma função e a mesma documentação do .isnull()(retorna as linhas que possuem valor missing)

df[df['col3'].isna()]
# Out:
#    col1  col2  col3
# 1   NaN  15.0   NaN
# 2  16.0   1.0   NaN

# %%
#.any() analisa tanto linha quanto coluna  conforme a instrução anterior
#No nosso exemplo a intrução anterior é .isnull()

df[df.isnull().any(axis=1)]
# Out:
#    col1  col2  col3
# 0   6.0   NaN  15.0
# 1   NaN  15.0   NaN
# 2  16.0   1.0   NaN

# %%
# Nessa próxima função eu estou pedindo para o colab imprimir apenas as linhas que possuem mais de um NaN.
# Para que isso aconteça é necessário somar a quantidade de missing que aparecem.

df[df.isnull().sum(axis=1) == 2]
# Out:
#    col1  col2  col3
# 1   NaN  15.0   NaN
